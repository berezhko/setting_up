# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pylab.rcParams['figure.figsize'] = (20, 11.0)
pylab.rcParams['font.family'] = "serif"
pylab.rcParams['font.size'] = 16

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import io

# %%
def iter_Coll(author, param):
    doc_dict = {}
    for doc in author[param]:
        doc_dict = author.attrib.copy()
        if param == 0:
            doc_dict.update({'Ток': float(doc.attrib['Amper']), 'Напряжение': float(doc.attrib['Volt'])})
        else:
            a = doc.attrib['AmperAdd'].split(" ")[0]
            v = doc.attrib['VoltAdd'].split(" ")[0]
            doc_dict.update({'Ток': a, 'Напряжение': v})
        yield doc_dict

# %%
def cacl_last(df, phase, wire):
    x = []
    for k in df[phase+wire].tail(2)["Ток"].keys():
        x.append(k)

    x2 = df[phase+wire].tail(2)["Ток"][x[1]]
    y2 = df[phase+wire].tail(2)["Напряжение"][x[1]]

    x1 = df[phase+wire].tail(2)["Ток"][x[0]]
    y1 = df[phase+wire].tail(2)["Напряжение"][x[0]]

    return round((4 - x1)*(y2 - y1)/(x2 - x1) + y1, 2)

# %%
doc_df = {}

# %%
TT = "TA1A"
with open("ТТ_"+ TT + "_29.5.2023.r21_transI", encoding="utf-8") as f:
    etree = ET.parse(f)

# %%
pd.DataFrame(list(iter_Coll(etree.getroot()[1], 1))).T.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_a0846a9e_0037_11ee_9831_3c9509678ebe" ><thead>    <tr>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow0_col0" class="data row0 col0" >0,2</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow0_col1" class="data row0 col1" >0,5</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow0_col3" class="data row0 col3" >2</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow0_col4" class="data row0 col4" >3</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow0_col5" class="data row0 col5" >5</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow0_col6" class="data row0 col6" ></td>
#             </tr>
#             <tr>
#                                 <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow1_col0" class="data row1 col0" >4,05</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow1_col1" class="data row1 col1" >4,29</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow1_col2" class="data row1 col2" >4,4</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow1_col3" class="data row1 col3" >4,51</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow1_col4" class="data row1 col4" >4,57</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow1_col5" class="data row1 col5" >4,7</td>
#                         <td id="T_a0846a9e_0037_11ee_9831_3c9509678eberow1_col6" class="data row1 col6" ></td>
#             </tr>
#     </tbody></table>

# %%
doc_df[TT] = pd.DataFrame(list(iter_Coll(etree.getroot()[1], 0)))

# %%
pie = doc_df[TT].plot(x="Ток", grid=True, ylabel="Напряжение", legend = False)
pie.get_figure().savefig(TT + ".png", bbox_inches='tight', pad_inches=0.1)

# %%
wire = "404"
for TT in ["A", "B", "C"]:
    plot(doc_df[TT+wire]["Ток"], doc_df[TT+wire]["Напряжение"], label="фаза " + TT)
    print(TT, cacl_last(doc_df, TT, wire))
legend()
grid()
savefig(wire + ".png", bbox_inches='tight', pad_inches=0.1)
# Out:
# A 574.09
# B 566.19
# C 569.81

# %%
# Out:
# 545.0130671647426
